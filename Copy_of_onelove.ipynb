# %% [markdown]
# <a href="https://colab.research.google.com/github/BesuDev195/Alpha_Electronics/blob/main/Copy_of_onelove.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple code example
print("Hello, I am safe in Google Drive!")
print("one love for ever")
for i in range(3):
    print("Counting:", i)
# Out:
# Hello, I am safe in Google Drive!
# one love for ever
# Counting: 0
# Counting: 1
# Counting: 2
